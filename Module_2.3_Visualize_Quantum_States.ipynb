# %% [markdown]
# # Qiskit Certification Prep - Module 2.3: Visualize Quantum Measurements

# %%
import numpy as np
from qiskit.visualization import plot_bloch_vector
 
plot_bloch_vector([0,1,0], title="New Bloch Sphere")

# %%
from qiskit.visualization import plot_bloch_vector
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector, SparsePauliOp

qc = QuantumCircuit(1)
qc.rx(np.pi/2, 0)

sv = Statevector.from_instruction(qc)
x = float(np.real(sv.expectation_value(SparsePauliOp('X'))))
y = float(np.real(sv.expectation_value(SparsePauliOp('Y'))))
z = float(np.real(sv.expectation_value(SparsePauliOp('Z'))))
plot_bloch_vector([x,y,z], title="New Bloch Sphere")

# %%
from qiskit.visualization import plot_bloch_vector
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector, SparsePauliOp

qc = QuantumCircuit(1)
qc.ry(np.pi/2, 0)

sv = Statevector.from_instruction(qc)
x = float(np.real(sv.expectation_value(SparsePauliOp('X'))))
y = float(np.real(sv.expectation_value(SparsePauliOp('Y'))))
z = float(np.real(sv.expectation_value(SparsePauliOp('Z'))))
plot_bloch_vector([x,y,z], title="New Bloch Sphere")
